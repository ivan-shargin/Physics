# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn import linear_model

# %%
l = np.array([0, 0.48, 0.93, 1.33, 1.80, 2.28, 2.78])
N_plus_phon = np.array([1650973, 858713, 405663, 193967, 105621, 58347, 31335])
N = N_plus_phon - 1539
ln_N = np.log(N)
delta_lnN = 1 / np.sqrt(N)
delta_l = np.linspace(0, 6 * 0.005, 7)

fig, ax = plt.subplots() 
ax.grid()
ax.scatter(l, ln_N, s=7)
ax.errorbar(l, ln_N, yerr=delta_lnN, xerr=delta_l, linestyle = '')
plt.xlabel("l, sm")
plt.ylabel("ln(N)")

linear_regressor = linear_model.LinearRegression()
linear_regressor.fit(l[1:-2].reshape((l[1:-2].size, 1)), ln_N[1:-2])
x0 = np.linspace(0, 3, 150).reshape((150, 1))
y0 = linear_regressor.predict(x0)
ax.plot(x0, y0)
print(linear_regressor.coef_)


fig.savefig('5_1_1')
# Out:
# [-1.61809934]

# %%
l = np.array([0, 1.01, 2.01, 3.02, 4.03, 5.04, 6.04, 7.06, 8.07])
N_plus_phon = np.array([1650973, 800388, 370495, 184148, 97807, 52068, 29782, 16931, 10050])
N = N_plus_phon - 1539
ln_N = np.log(N)
delta_lnN = 1 / np.sqrt(N)
delta_l = np.linspace(0, 6 * 0.005, 9)

fig, ax = plt.subplots() 
ax.grid()
ax.scatter(l, ln_N, s=7)
ax.errorbar(l, ln_N, yerr=delta_lnN, xerr=delta_l, linestyle = '')
plt.xlabel("l, sm")
plt.ylabel("ln(N)")

linear_regressor = linear_model.LinearRegression()
linear_regressor.fit(l[1:-2].reshape((l[1:-2].size, 1)), ln_N[1:-2])
x0 = np.linspace(0, 8.5, 150).reshape((150, 1))
y0 = linear_regressor.predict(x0)
ax.plot(x0, y0)
print(linear_regressor.coef_)


fig.savefig('5_1_2')
# Out:
# [-0.66144484]

# %%
l = np.array([0, 2, 4.01, 6.02, 8.03, 10.03, 12.02, 14.02])
N_plus_phon = np.array([1650973, 1028981, 548706, 319122, 198318, 126456, 81336, 54095])
N = N_plus_phon - 1539
ln_N = np.log(N)
delta_lnN = 1 / np.sqrt(N)
delta_l = np.linspace(0, 6 * 0.005, 8)

fig, ax = plt.subplots() 
ax.grid()
ax.scatter(l, ln_N, s=7)
ax.errorbar(l, ln_N, yerr=delta_lnN, xerr=delta_l, linestyle = '')
plt.xlabel("l, sm")
plt.ylabel("ln(N)")

linear_regressor = linear_model.LinearRegression()
linear_regressor.fit(l[1:-2].reshape((l[1:-2].size, 1)), ln_N[1:-2])
x0 = np.linspace(0, 14.5, 150).reshape((150, 1))
y0 = linear_regressor.predict(x0)
ax.plot(x0, y0)
print(linear_regressor.coef_)


fig.savefig('5_1_3')
# Out:
# [-0.2608211]
